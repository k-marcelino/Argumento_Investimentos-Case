# %% [markdown]
# Para fazer uma avaliação sobre os conhecimentos de Python, segue um breve exercício que simula o cálculo de cotas e retornos de uma carteira hipotética.
#
# Para executar este código recomendamos o uso do Python seja no jupyter notebook ou jupyter lab.
# Isso pode ser feito online, sem ter instalado o software no endereço:
# https://jupyter.org/try
#
# necessitando fazer upload dos arquivos no site

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
#### Carrega informações

# cota
COTA = pd.read_csv('COTA.csv', delimiter = ';')
COTA['DATA'] = pd.to_datetime(COTA['DATA'], format='%d/%m/%Y')

# histórico de operações de compra e venda
OPERACOES = pd.read_csv('OPERACOES.csv', delimiter = ';')
OPERACOES['DATA'] = pd.to_datetime(OPERACOES['DATA'], format='%d/%m/%Y')

# movimentações de conta corrente depósitos e saques
MOV_CC = pd.read_csv('CONTAC.csv', delimiter = ';')
MOV_CC['DATA'] = pd.to_datetime(MOV_CC['DATA'], format='%d/%m/%Y')

# preços dos ativos
PRECOS = pd.read_csv('PRECOS.csv', delimiter = ';')
PRECOS['DATA'] = pd.to_datetime(PRECOS['DATA'], format='%d/%m/%Y')

# %% [markdown]
# ### QUESTÃO 1
#
# Temos um problema nesta leitura de dados anterior pois os valores que deveriam ser interpretados como números, com separação de **decimal** e de **milhar**, estão sendo interpretados como texto. Todos arquivos tem uma váriavel que deve ser interpretados como float64.
# Favor **corrigir o código acima** para que os resultados dos dtypes abaixo sejam:
#
#
# QTD               int64
#
# PRECO           float64
#
# PATR            float64
#
# ATIVO            object

# %%
# COTA.head()
COTA.dtypes
# Out:
# DATA     datetime64[ns]
# QTD               int64
# PRECO           float64
# PATR            float64
# dtype: object

# %%
#OPERACOES.head()
OPERACOES.dtypes
# Out:
# DATA     datetime64[ns]
# MOV              object
# QTD             float64
# PRECO           float64
# ATIVO            object
# dtype: object

# %%
#MOV_CC.head()
MOV_CC.dtypes
# Out:
# DATA    datetime64[ns]
# MOV            float64
# dtype: object

# %%
# PRECOS.head()
PRECOS.DATA
# Out:
# 0    2019-08-20
# 1    2019-08-19
# 2    2019-08-15
# 3    2019-08-14
# 4    2019-08-13
#         ...
# 81   2019-06-26
# 82   2019-06-25
# 83   2019-06-24
# 84   2019-06-21
# 85   2019-06-20
# Name: DATA, Length: 86, dtype: datetime64[ns]

# %%
# troca sinal da quantidade em ordens de compra (positivo) e venda (negativo)
# para padronizar como processaremos as ordens

for row, i in OPERACOES.iterrows():
    if i.MOV == 'V':
        OPERACOES.loc[row,'QTD'] =-i.QTD

OPERACOES.head()
# Out:
#         DATA MOV    QTD    PRECO ATIVO
# 0 2019-06-20   C   27.0  1851.85     A
# 1 2019-06-20   C  442.0   113.12     B
# 2 2019-07-11   V -178.0   112.60     B

# %%
# popula histórico POSICAO
# aqui processamos todas as ordens e montamos um histórico de posição
# dizendo se a carteira estava comprada ou não em um ativo dia a dia

POS_AT = pd.DataFrame({'DATA':pd.Series([], dtype = 'datetime64[ns]'),
                       'ATIVO':pd.Series([], dtype ='str'),
                       'POS':pd.Series([], dtype = 'float')})

for row, i in OPERACOES.iterrows():
    POS_AT_SW = pd.DataFrame({'DATA':pd.Series([], dtype = 'datetime64[ns]'),
                              'ATIVO':pd.Series([], dtype = 'str'),
                              'POS':pd.Series([], dtype = 'float')})
    POS_AT_SW.DATA = PRECOS.loc[(PRECOS.DATA >= i.DATA) & (PRECOS.ATIVO == i.ATIVO)].DATA.unique()
    POS_AT_SW.ATIVO = i.ATIVO
    POS_AT_SW.POS = i.QTD
    POS_AT = POS_AT.append(POS_AT_SW).reset_index(drop = True)

POS_AT = POS_AT.groupby(['ATIVO','DATA'], as_index = False).sum()

# %%
POS_AT
# Out:
#    ATIVO       DATA    POS
# 0      A 2019-06-20   27.0
# 1      A 2019-06-21   27.0
# 2      A 2019-06-24   27.0
# 3      A 2019-06-25   27.0
# 4      A 2019-06-26   27.0
# ..   ...        ...    ...
# 81     B 2019-08-13  264.0
# 82     B 2019-08-14  264.0
# 83     B 2019-08-15  264.0
# 84     B 2019-08-19  264.0
# 85     B 2019-08-20  264.0
#
# [86 rows x 3 columns]

# %%
# popula histórico da Conta Corrente que deve ter o impacto:
# 1 - das movimentações de aplicações e resgates
# 2 - das operações de compra e venda de ativos

POS_CC = pd.DataFrame({'DATA':pd.Series([], dtype = 'datetime64[ns]'),
                       'SALDO':pd.Series([], dtype = 'float')})
POS_CC.DATA = MOV_CC.DATA[0:1]
POS_CC.SALDO = MOV_CC.MOV[0:1]

# POPULA MOVIMENTAÇÕES NA CC
for row, i in MOV_CC.iterrows():
    POS_CC_SW = pd.DataFrame({'DATA':pd.Series([], dtype = 'datetime64[ns]'),
                              'SALDO':pd.Series([], dtype = 'float')})
    POS_CC_SW.DATA = PRECOS.loc[PRECOS.DATA >= i.DATA].DATA.unique()
    POS_CC_SW.SALDO = i.MOV
    POS_CC = POS_CC.append(POS_CC_SW).reset_index(drop = True)

# popula histórico OPERAÇÕES NA CC
for row, i in OPERACOES.iterrows():
    POS_CC_SW = pd.DataFrame({'DATA':pd.Series([], dtype = 'datetime64[ns]'),
                              'SALDO':pd.Series([], dtype = 'float')})
    POS_CC_SW.DATA = PRECOS.loc[(PRECOS.DATA >= i.DATA) & (PRECOS.ATIVO == i.ATIVO)].DATA.unique()
    POS_CC_SW.SALDO =-i.QTD*i.PRECO # Se compra ativo, debita da conta. Se vende, deposita.
    POS_CC = POS_CC.append(POS_CC_SW).reset_index(drop = True)

# %%
#POS_CC.groupby(['DATA']).sum()
POS_CC.head()
# Out:
#         DATA     SALDO
# 0 2019-06-19  100000.0
# 1 2019-08-20  100000.0
# 2 2019-08-19  100000.0
# 3 2019-08-15  100000.0
# 4 2019-08-14  100000.0

# %%
# Preparação para CÁLCULO DO RESULTADO
# aqui montamos uma nova tabela para processarmos o resultado diário (PNL = profit and loss)

PNL = POS_AT.merge(OPERACOES, how = 'left', left_on = ['DATA','ATIVO'], right_on = ['DATA','ATIVO'])
PNL = PNL.rename(columns = {'PRECO': "PRECO_MOV"})
PNL = PNL.merge(PRECOS, how = 'left', left_on = ['DATA','ATIVO'], right_on = ['DATA','ATIVO'])
PNL['PRECOANT'] = pd.Series([], dtype = 'float')

for i in PNL.ATIVO.unique():
    PNL.loc[PNL.ATIVO == i,'PRECOANT'] = PNL.loc[PNL.ATIVO == i].PRECO.shift(periods = 1)

PNL['POS$'] = PNL['POS']*PNL['PRECO']

# cálculo do patrimônio diário
PATR = pd.concat([PNL[['DATA','POS$']].groupby(['DATA'], as_index = False).sum().rename(columns = {'POS$':'PATR'}),
           POS_CC.groupby(['DATA']).sum().rename(columns = {'SALDO': 'PATR'})],
           ignore_index = True, sort = True).groupby(['DATA'], as_index = False).sum()

# %%
PNL
# Out:
#    ATIVO       DATA    POS  MOV   QTD  PRECO_MOV    PRECO  PRECOANT      POS$
# 0      A 2019-06-20   27.0    C  27.0    1851.85  1851.85       NaN  49999.95
# 1      A 2019-06-21   27.0  NaN   NaN        NaN  1854.17   1851.85  50062.59
# 2      A 2019-06-24   27.0  NaN   NaN        NaN  1853.52   1854.17  50045.04
# 3      A 2019-06-25   27.0  NaN   NaN        NaN  1851.66   1853.52  49994.82
# 4      A 2019-06-26   27.0  NaN   NaN        NaN  1853.77   1851.66  50051.79
# ..   ...        ...    ...  ...   ...        ...      ...       ...       ...
# 81     B 2019-08-13  264.0  NaN   NaN        NaN   112.87    113.25  29797.68
# 82     B 2019-08-14  264.0  NaN   NaN        NaN   112.85    112.87  29792.40
# 83     B 2019-08-15  264.0  NaN   NaN        NaN   112.50    112.85  29700.00
# 84     B 2019-08-19  264.0  NaN   NaN        NaN   112.50    112.50  29700.00
# 85     B 2019-08-20  264.0  NaN   NaN        NaN   112.50    112.50  29700.00
#
# [86 rows x 9 columns]

# %%
 PATR.head()
# Out:
#         DATA      PATR
# 0 2019-06-20  99998.99
# 1 2019-06-21  99787.59
# 2 2019-06-24  99730.26
# 3 2019-06-25  99671.20
# 4 2019-06-26  99648.61

# %%
# cálculo da cota diária

COTA = COTA.append(PATR, ignore_index = True, sort = False).reset_index(drop = True)
COTA.QTD = COTA.iloc[0].QTD
COTA.PRECO = COTA.PATR/COTA.QTD

# POPULA COTAS com Movimentações de CC 
for row, i in MOV_CC.iterrows():
    if row > 0:
        COTA.loc[COTA.DATA >= i.DATA,'QTD'] = (COTA.loc[COTA.DATA == i.DATA,'QTD'].values[0] + 
                                               i.MOV/COTA.loc[COTA.DATA.shift(periods = -1) == i.DATA,'PRECO'].values[0])
        COTA.PRECO = COTA.PATR/COTA.QTD

# %%
COTA.head()
# Out:
#         DATA    QTD      PRECO       PATR
# 0 2019-06-19  100.0  1000.0000  100000.00
# 1 2019-06-20  100.0   999.9899   99998.99
# 2 2019-06-21  100.0   997.8759   99787.59
# 3 2019-06-24  100.0   997.3026   99730.26
# 4 2019-06-25  100.0   996.7120   99671.20

# %%
COTA[['DATA','PRECO']].plot(x = 'DATA', y = 'PRECO', kind = 'line')
# Out:
# <AxesSubplot:xlabel='DATA'>

# %%
# CÁLCULO DO RESULTADO

PNL = PNL.fillna(0) # preenche vazios com zero
PNL = PNL.merge(PATR, how = 'left', left_on = ['DATA'], right_on = ['DATA']) # insere coluna com patrimônio diário

PNL
# Out:
#    ATIVO       DATA    POS MOV   QTD  PRECO_MOV    PRECO  PRECOANT      POS$  \
# 0      A 2019-06-20   27.0   C  27.0    1851.85  1851.85      0.00  49999.95
# 1      A 2019-06-21   27.0   0   0.0       0.00  1854.17   1851.85  50062.59
# 2      A 2019-06-24   27.0   0   0.0       0.00  1853.52   1854.17  50045.04
# 3      A 2019-06-25   27.0   0   0.0       0.00  1851.66   1853.52  49994.82
# 4      A 2019-06-26   27.0   0   0.0       0.00  1853.77   1851.66  50051.79
# ..   ...        ...    ...  ..   ...        ...      ...       ...       ...
# 81     B 2019-08-13  264.0   0   0.0       0.00   112.87    113.25  29797.68
# 82     B 2019-08-14  264.0   0   0.0       0.00   112.85    112.87  29792.40
# 83     B 2019-08-15  264.0   0   0.0       0.00   112.50    112.85  29700.00
# 84     B 2019-08-19  264.0   0   0.0       0.00   112.50    112.50  29700.00
# 85     B 2019-08-20  264.0   0   0.0       0.00   112.50    112.50  29700.00
#
#     PNL$      PATR
# 0    0.0  99998.99
# 1    0.0  99787.59
# 2    0.0  99730.26
# 3    0.0  99671.20
# 4    0.0  99648.61
# ..   ...       ...
# 81   0.0  79899.96
# 82   0.0  79533.15
# 83   0.0  79462.35
# 84   0.0  79462.35
# 85   0.0  79462.35
#
# [86 rows x 11 columns]

# %% [markdown]
# ### Nesta variável PNL temos, para todas as datas:
# - as posições de fechamento dos ativos (POS),
# - as movimentações (QTD),
# - o preço em que a movimentação ocorreu (PRECO_MOV),
# - preço de fechamento (PRECO)
# - o preco do dia anterior (PRECOANT)

# %% [markdown]
# ### QUESTÃO 2
#
# Faça o Cálculo do Resultado Financeiro **diário** na fórmula na célula abaixo.
#
# O resultado financeiro da carteira pode ser visto como a soma de duas partes:
#
# 1. O resultado da posição que a carteira carrega de um dia para o outro.
#    Exemplo: a carteira tinha 100 ações que passaram de um valor de R 10,00 para R 10,10 de um dia para o outro.
#    O resultado diário correspondente a essa variação de preço é (10,10 - 10,00) * 100 = 10,00
#
# 2. O resultado de alguma movimentação que tenha sido feita na carteira (compra ou venda).
#    Durante o dia comprou-se 100 ações por R 10,00 que encerraram o dia valendo R 9,90.
#    O resultado diário correspondente a esta operação de compra é (9,90 - 10,00)* 100 = -10,00
#
# é possivel escrever esta equação que calcula o resultado diário da carteira usando as colunas da variável PNL

# %%
# Cálcule do Resultado Financeiro usando as colunas da variável PNL

PNL['PNL$']=

# %%
PNL.head()

# %%
# RESULTADO FINANCEIRO 
# para conferencia o somatório do resultado deve ser: -493.84000000000185
PNL['PNL$'].sum()
# Out:
# -493.84000000000185

# %%
# RESULTADO PERCENTUAL
# Cálculo do Resuldado Percentual
PNL['PNL'] = np.log(1 + (PNL['PNL$'])/PNL['PATR'])
PNL.PNL.sum()
# Out:
# -0.007221627479839883

# %% [markdown]
# ###  QUESTÃO 3
#
# Usando a variável PNL calcule o resultado Percentual por ATIVO somando os resultados parciais

# %%
# RESULTADO POR ATIVO
#
# ATIVO 	PNL
# A 	-0.004516
# B 	-0.002706

# %% [markdown]
# ### QUESTÃO 4
#
# Proponha uma visualização gráfica, utilizando os dados disponíveis e bibliotecas do Python (ex.: Matplotlib, Seaborn, Ploty, etc), que *transmita a participação de cada ativo no resultado da carteira*.
#
# Não precisa ser algo complexo, o foco é que a informação seja transmitida de forma clara e rápida, se atenha ao objetivo do gráfico.
#
# Caso seja selecionado para a etapa de entrevista, pediremos uma pequena apresentação dos motivos que levaram a sua resposta e das ferramentas que utilizou.
